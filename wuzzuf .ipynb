# %%
import requests
from bs4 import BeautifulSoup
url = "https://wuzzuf.net/search/jobs/?a=navbl&q=data%20science%20jobs&start=2"
response=requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
title=soup.find("h1").get_text()
title
# Out:
# 'data science jobs Jobs in Egypt'

# %%
url0=soup.find("iframe")
ss=url0.get("src")
ss
# Out:
# 'https://www.googletagmanager.com/ns.html?id=GTM-WR5C77B'

# %%
jop=soup.find_all("div",attrs={"class":"css-1gatmva e1v1l3u10"})
for i in jop:
    print(i.find("a").get("href"))
# Out:
# https://wuzzuf.net/jobs/careers/Edentech-Egypt-78060
# None
# https://wuzzuf.net/jobs/careers/SABA-Egypt-32300
# https://wuzzuf.net/jobs/careers/Cash-Call-Egypt-39990
# https://wuzzuf.net/jobs/careers/Tarseya-Egypt-76749
# https://wuzzuf.net/jobs/careers/Worex-Egypt-58786
# https://wuzzuf.net/jobs/careers/Smart-System-Egypt-34555
# https://wuzzuf.net/jobs/careers/Worex-Egypt-58786
# None
# https://wuzzuf.net/jobs/careers/Unimix-Egypt-for-Readymix-concrete-Egypt-33631
# https://wuzzuf.net/jobs/careers/Zewail-City-Egypt-2881
# https://wuzzuf.net/jobs/careers/Next-care-health-Egypt-23989
# https://wuzzuf.net/jobs/careers/Fawry-Plus-Egypt-31117
# https://wuzzuf.net/jobs/careers/Olam-SVI-Egypt-24893
# https://wuzzuf.net/jobs/careers/BI-Technologies-Egypt-14526

# %%
url0=soup.find_all("div",attrs={"class":"css-pkv5jc"})
for i in url0:
    print(i.find("a").get("href"))
# Out:
# https://wuzzuf.net/jobs/careers/Edentech-Egypt-78060
# None
# https://wuzzuf.net/jobs/careers/SABA-Egypt-32300
# https://wuzzuf.net/jobs/careers/Cash-Call-Egypt-39990
# https://wuzzuf.net/jobs/careers/Tarseya-Egypt-76749
# https://wuzzuf.net/jobs/careers/Worex-Egypt-58786
# https://wuzzuf.net/jobs/careers/Smart-System-Egypt-34555
# https://wuzzuf.net/jobs/careers/Worex-Egypt-58786
# None
# https://wuzzuf.net/jobs/careers/Unimix-Egypt-for-Readymix-concrete-Egypt-33631
# https://wuzzuf.net/jobs/careers/Zewail-City-Egypt-2881
# https://wuzzuf.net/jobs/careers/Next-care-health-Egypt-23989
# https://wuzzuf.net/jobs/careers/Fawry-Plus-Egypt-31117
# https://wuzzuf.net/jobs/careers/Olam-SVI-Egypt-24893
# https://wuzzuf.net/jobs/careers/BI-Technologies-Egypt-14526

# %%
titlejop=soup.find_all("h2",attrs={"class":"css-m604qf"})
for i in titlejop:
    print(i.find("a").get_text())
# Out:
# Senior Data Engineer
# SAP Data Entry Team Leader
# Project Manager - Data Networks (ICT)
# Senior Data Engineer
# Data Scientist “Mathematics/Physics”
# Big Data Project Team Lead
# Data Center Engineer
# Big Data Engineer
# Business Data Administrator (KSA)
# Data Analyst
# Senior Biology Laboratory Specialist - Biomedical Sciences Program
# Processing Officer (Science Graduates)
# Business Data Analyst
# Data Analyst
# Power BI Developer

# %%
jopplace=soup.find_all("span",attrs={"class":"css-5wys0k"})
jopplace[0].text
for i in jopplace:
    print(i.text)
# Out:
# Cairo, Egypt
# 10th of Ramadan City, Cairo, Egypt
# Heliopolis, Cairo, Egypt
# Maadi, Cairo, Egypt
# Cairo, Egypt
# Riyadh, Saudi Arabia
# New Cairo, Cairo, Egypt
# Riyadh, Saudi Arabia
# Riyadh, Saudi Arabia
# Nasr City, Cairo, Egypt
# 6th of October, Giza, Egypt
# New Cairo, Cairo, Egypt
# Smart Village, Giza, Egypt
# 6th of October, Giza, Egypt
# New Cairo, Cairo, Egypt

# %%
description=soup.find_all("a",attrs={"class":"css-5x9pm1"})
for i in description:
    print(i.get_text())
# Out:
#  · Information Technology (IT)
# Computer Science
#  · Software Development
#  · Engineering
#  · Programming
#  · Communication skills
#  · Java
#  · Software
#  · SAP
#  · MS Office
# Data Entry
#  · Microsoft Excel
# Data
#  · English
#  · Typing
#  · Skills
#  · Administration
#  · Project Management
#  · Software Engineering
# Data Networks
#  · Networks
#  · PMP
#  · Microsoft Visio
#  · Smartdraw
#  · Database
#  · Information Technology (IT)
#  · IT
#  · ITIL
# Computer Science
#  · Software Development
#  · SQL
#  · Python
#  · Business Objects
# Computer Science
#  · D3
# Data Mining
#  · Gurobi
#  · Information Technology (IT)
#  · Mathematics
#  · Python
#  · Spark
# Big Data
#  · Computer Engineering
#  · Information Technology (IT)
# Computer Science
#  · Spark
# Data center
#  · Cisco
#  · Software Engineering
#  · Vmware
#  · Cloud Computing
#  · CCNP
#  · CCNA
#  · Servers
#  · Information Technology (IT)
#  · Computer Engineering
#  · Kafka
# Computer Science
# ...

# %%
companyname=soup.find_all("div",attrs={"class","css-d7j1kk"})
for i in companyname:
    print(i.find("a").get_text()[:-1])
# Out:
# Edentech
# Confidential
# SABA
# Cashcall
# Dafa
# Worex
# Smart System
# Worex
# Confidential
# Unimix Egypt for Readymix concrete
# Zewail City
# NEXtCARE
# Fawry Plus
# Olam SVI
# BI-Technologies

# %%
lastpage=soup.find("ul",attrs={"class","css-e5a93e"})
ss=pagenum.find("button",attrs={"class":"css-18rqtbx ezfki8j0"})
last_page=int(ss.get_text())
last_page
# Out:
# 43

# %%
import csv
import requests
from bs4 import BeautifulSoup
lastpage=soup.find("ul",attrs={"class","css-e5a93e"})
ss=pagenum.find("button",attrs={"class":"css-18rqtbx ezfki8j0"})
last_page=int(ss.get_text())
header = ['link' , 'title' , 'location','description','company name'] 
with open('wuzzuf__1.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    for i in range(1,last_page+1):
        url = f"https://wuzzuf.net/search/jobs/?a=navbl&q=data%20science%20jobs&start={i}"
        response=requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        url0=soup.find_all("div",attrs={"class":"css-pkv5jc"})
        for i in url0:
            kk=i.find("a").get("href")
            print(kk)
        titlejop=soup.find_all("h2",attrs={"class":"css-m604qf"})
        for i in titlejop:
            mm=i.find("a").get_text()
            print(mm)
        jopplace=soup.find_all("span",attrs={"class":"css-5wys0k"})
        for i in jopplace:
            bb=i.text
            print(bb)
        description=soup.find_all("a",attrs={"class":"css-5x9pm1"})
        for i in description:
            cc=i.get_text()
            print(cc)
        companyname=soup.find_all("div",attrs={"class","css-d7j1kk"})
        for i in companyname:
            gg=i.find("a").get_text()[:-1]
            print(gg)
        writer.writerow([ kk ,  mm , bb , cc , gg])
# Out:
# https://wuzzuf.net/jobs/careers/Z2-Data-Egypt-10002
# None
# https://wuzzuf.net/jobs/careers/Z2-Data-Egypt-10002
# https://wuzzuf.net/jobs/careers/Z2-Data-Egypt-10002
# https://wuzzuf.net/jobs/careers/Z2-Data-Egypt-10002
# https://wuzzuf.net/jobs/careers/Arma-Egypt-73932
# https://wuzzuf.net/jobs/careers/GlobeMed-Egypt-Egypt-3854
# https://wuzzuf.net/jobs/careers/United-Grocers-Egypt-16038
# https://wuzzuf.net/jobs/careers/EpsilonAI-Egypt-65111
# https://wuzzuf.net/jobs/careers/WUZZUF-Egypt-15061
# https://wuzzuf.net/jobs/careers/Smart-System-Egypt-34555
# https://wuzzuf.net/jobs/careers/Worex-Egypt-58786
# https://wuzzuf.net/jobs/careers/elmoasserbooks-Egypt-37460
# https://wuzzuf.net/jobs/careers/safran-Group-Egypt-10469
# https://wuzzuf.net/jobs/careers/SABA-Egypt-32300
# Senior Data Engineer- Banha
# Data Engineer - KSA
# Senior Data Analyst
# Data Analyst - Banha
# Junior Data Analyst
# Data Analyst
# Data Analyst| MIS
# Data Scientist
# ...

# %%
ss=pagenum.find("button",attrs={"class":"css-18rqtbx ezfki8j0"})
last_page=int(ss.get_text())
for i in range(1,last_page+1):
    url = f"https://wuzzuf.net/search/jobs/?a=navbl&q=data%20science%20jobs&start={i}"
    print(url)
# Out:
# https://wuzzuf.net/search/jobs/?a=navbl&q=data%20science%20jobs&start=1
# https://wuzzuf.net/search/jobs/?a=navbl&q=data%20science%20jobs&start=2
# https://wuzzuf.net/search/jobs/?a=navbl&q=data%20science%20jobs&start=3
# https://wuzzuf.net/search/jobs/?a=navbl&q=data%20science%20jobs&start=4
# https://wuzzuf.net/search/jobs/?a=navbl&q=data%20science%20jobs&start=5
# https://wuzzuf.net/search/jobs/?a=navbl&q=data%20science%20jobs&start=6
# https://wuzzuf.net/search/jobs/?a=navbl&q=data%20science%20jobs&start=7
# https://wuzzuf.net/search/jobs/?a=navbl&q=data%20science%20jobs&start=8
# https://wuzzuf.net/search/jobs/?a=navbl&q=data%20science%20jobs&start=9
# https://wuzzuf.net/search/jobs/?a=navbl&q=data%20science%20jobs&start=10
# https://wuzzuf.net/search/jobs/?a=navbl&q=data%20science%20jobs&start=11
# https://wuzzuf.net/search/jobs/?a=navbl&q=data%20science%20jobs&start=12
# https://wuzzuf.net/search/jobs/?a=navbl&q=data%20science%20jobs&start=13
# ...
